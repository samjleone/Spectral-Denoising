# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import pygsp
from tqdm import tqdm
import torch
from torch import optim
import spectral_denoiser as sd

# %% [markdown]
# # Load Image and Create Graph

# %%
N = 100
noodle = Image.open("noodle.jpg").resize((N,N))
noodle_array = np.asarray(noodle)
noodle_cropped = noodle_array
G = pygsp.graphs.Grid2d(N)

# %% [markdown]
# # Create an Instance

# %%
denoiser = sd.Spectral_Denoiser(G)

# %% [markdown]
# # Gaussian Noise

# %%
noodle_gray = np.mean(noodle_cropped, axis = 2)
f_tilde = noodle_gray.reshape(-1) + 50*np.random.randn(N*N)

# %%
fig, ax = plt.subplots(1,4,figsize=(10,40))
ax[0].imshow(noodle_gray.reshape(N,N), cmap = 'inferno')
ax[0].set_title("True Signal")
ax[0].axis("off")

ax[1].imshow(f_tilde.reshape(N,N), cmap = 'inferno')
ax[1].set_title("Noisy Signal")
ax[1].axis("off")

f_check = denoiser.remove_gaussian_noise(f_tilde,tau=2)
ax[2].imshow(f_check.reshape(N,N), cmap = 'inferno')
ax[2].set_title("Denoised Signal\n (tau = 2)")
ax[2].axis("off")

f_check = denoiser.remove_gaussian_noise(f_tilde,tau=10)
ax[3].imshow(f_check.reshape(N,N), cmap = 'inferno')
ax[3].set_title("Denoised Signal\n (tau = 10)")
ax[3].axis("off")
plt.show()
# Out:
# 2022-11-29 18:58:29,801:[WARNING](pygsp.graphs.graph.lmax): The largest eigenvalue G.lmax is not available, we need to estimate it. Explicitly call G.estimate_lmax() or G.compute_fourier_basis() once beforehand to suppress the warning.

# %% [markdown]
# # Bernoulli Noise

# %%
z = 1*(np.random.randn(N,N) > 1)
noodle_gray = np.mean(noodle_cropped, axis = 2)
f_tilde = z*noodle_gray

# %%
denoised = denoiser.remove_bernoulli_noise(f_tilde)

# %%
fig, ax = plt.subplots(1,3,figsize=(10,30))
ax[0].imshow(noodle_gray.reshape(N,N), cmap = 'inferno')
ax[0].set_title("True Signal")
ax[0].axis("off")

ax[1].imshow(f_tilde, cmap = 'inferno')
ax[1].set_title("Noisy Signal")
ax[1].axis("off")

ax[2].imshow(denoised.reshape(N,N), cmap = 'inferno')
ax[2].set_title("Denoised Signal")
ax[2].axis("off")
plt.show()

# %%
import importlib
importlib.reload(sd)
denoiser = sd.Spectral_Denoiser(G)

# %%
z = 1*(np.random.randn(N,N) > 2)
noodle_gray = np.mean(noodle_cropped, axis = 2)
f_tilde = z*noodle_gray

# %%
denoised = denoiser.remove_bernoulli_noise_2(f_tilde, time = 200)
# Out:
# 100%|███████████████████████████████████████████| 50/50 [00:02<00:00, 24.69it/s]

# %%
fig, ax = plt.subplots(1,3,figsize=(10,30))
ax[0].imshow(noodle_gray.reshape(N,N), cmap = 'inferno')
ax[0].set_title("True Signal")
ax[0].axis("off")

ax[1].imshow(f_tilde, cmap = 'inferno')
ax[1].set_title("Noisy Signal")
ax[1].axis("off")

ax[2].imshow(denoised.reshape(N,N), cmap = 'inferno')
ax[2].set_title("Denoised Signal")
ax[2].axis("off")
plt.show()

# %% [markdown]
# # Uniform Noise

# %%
f_tilde = noodle_gray.reshape(-1) * np.random.uniform(0,1,G.N)

# %%
f_check = denoiser.remove_uniform_noise(f_tilde,alpha=1,beta=1,gamma=1, lr = 5, MAX_ITER=1000)
# Out:
# /Users/samuelleone/Documents/GitHub/Spectral-Denoising/spectral_denoiser.py:124: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.tensor(signal.clone(), requires_grad = True)
# 100%|███████████████████████████████████████| 1000/1000 [02:05<00:00,  7.96it/s]

# %%
fig, ax = plt.subplots(1,3,figsize=(10,30))
ax[0].imshow(noodle_gray,cmap='inferno')
ax[0].set_title("Original Signal")
ax[1].imshow(f_tilde.reshape(N,N),cmap='inferno')
ax[1].set_title("Noisy Signal")
ax[2].imshow(f_check.reshape(N,N),cmap='inferno')
ax[2].set_title("Denoised Signal")
ax[0].axis("off"); ax[1].axis("off"); ax[2].axis("off");
fig.show()
# Out:
# /var/folders/vv/h1bxm3t15sx2m3r40_nzb0sr0000gn/T/ipykernel_7023/3662242174.py:9: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ## No Distance Reweighting

# %%
import importlib
importlib.reload(sd)
denoiser = sd.Spectral_Denoiser(G)

# %%
f_check = denoiser.remove_uniform_noise(f_tilde,alpha=1,beta=1,gamma=0, lr = 5, MAX_ITER=1000)
# Out:
#   0%|                                                  | 0/1000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [26], in <cell line: 1>()
# ----> 1 f_check = denoiser.remove_uniform_noise(f_tilde,alpha=1,beta=1,gamma=0, lr = 5, MAX_ITER=1000)
#
# File ~/Documents/GitHub/Spectral-Denoising/spectral_denoiser.py:135, in Spectral_Denoiser.remove_uniform_noise(self, f_tilde, lr, alpha, beta, gamma, MAX_ITER)
#     131 # Do the corresponding optimization
#     132 for i in tqdm(range(MAX_ITER)):
#     133
#     134     # calculate loss and perform the iterative step
# --> 135     l = loss(x, signal)
#     136     l.backward()
#     137     opt.step()
#
# File ~/Documents/GitHub/Spectral-Denoising/spectral_denoiser.py:112, in Spectral_Denoiser.remove_uniform_noise.<locals>.loss(z, signal)
#     110 def loss(z, signal):
#     111     # Calculte the Laplacian Quadratic Form
# --> 112     smoothness_prior = z.reshape(1,-1)@L_tens@z
#     114     # The Posterior / Prior Probability of the Signal
#     115     noise_prob = torch.sum(torch.log(torch.abs(z)))
#
# KeyboardInterrupt:

# %%
fig, ax = plt.subplots(1,3,figsize=(10,30))
ax[0].imshow(noodle_gray,cmap='gray')
ax[0].set_title("Original Signal")
ax[1].imshow(f_tilde.reshape(N,N),cmap='gray')
ax[1].set_title("Noisy Signal")
ax[2].imshow(f_check.reshape(N,N),cmap='gray')
ax[2].set_title("Denoised Signal")
ax[0].axis("off"); ax[1].axis("off"); ax[2].axis("off");
fig.show()
# Out:
# /var/folders/vv/h1bxm3t15sx2m3r40_nzb0sr0000gn/T/ipykernel_7023/3630577711.py:9: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
f_check = denoiser.remove_uniform_noise_2(f_tilde,alpha=1,beta=1, lr = 10000, MAX_ITER=100)
# Out:
#   1%|▍                                          | 1/100 [00:01<03:04,  1.86s/it]
# [[37638.07943371]]
#   2%|▊                                          | 2/100 [00:02<01:59,  1.22s/it]
# [[37638.87402464]]
#   3%|█▎                                         | 3/100 [00:03<01:29,  1.09it/s]
# [[37639.66837084]]
#   4%|█▋                                         | 4/100 [00:03<01:14,  1.29it/s]
# [[37640.46247219]]
#   5%|██▏                                        | 5/100 [00:04<01:05,  1.44it/s]
# [[37641.25632857]]
#   6%|██▌                                        | 6/100 [00:04<01:00,  1.55it/s]
# [[37642.04993985]]
#   7%|███                                        | 7/100 [00:05<00:59,  1.56it/s]
# [[37642.8433059]]
#   8%|███▍                                       | 8/100 [00:06<00:59,  1.55it/s]
# [[37643.63642659]]
#   8%|███▍                                       | 8/100 [00:06<01:16,  1.20it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [50], in <cell line: 1>()
# ----> 1 f_check = denoiser.remove_uniform_noise_2(f_tilde,alpha=1,beta=1, lr = 10000, MAX_ITER=100)
#
# File ~/Documents/GitHub/Spectral-Denoising/spectral_denoiser.py:184, in Spectral_Denoiser.remove_uniform_noise_2(self, f_tilde, lr, alpha, beta, MAX_ITER)
#     181 # Do the corresponding optimization
#     182 for i in tqdm(range(MAX_ITER)):
# --> 184     x_grad = beta_ * 1/x + 2 * alpha_ * L@x
#     185     x_grad = x_grad.reshape(-1,1)
#     186     x = x - lr * x_grad
#
# KeyboardInterrupt:

# %%
fig, ax = plt.subplots(1,3,figsize=(10,30))
ax[0].imshow(noodle_gray,cmap='gray')
ax[0].set_title("Original Signal")
ax[1].imshow(f_tilde.reshape(N,N),cmap='gray')
ax[1].set_title("Noisy Signal")
ax[2].imshow(f_check.reshape(N,N),cmap='gray')
ax[2].set_title("Denoised Signal")
ax[0].axis("off"); ax[1].axis("off"); ax[2].axis("off");
fig.show()
# Out:
# /var/folders/vv/h1bxm3t15sx2m3r40_nzb0sr0000gn/T/ipykernel_7023/3630577711.py:9: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
