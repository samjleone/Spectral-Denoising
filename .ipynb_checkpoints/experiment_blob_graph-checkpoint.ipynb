# %%
from experiment_utils import generate_blob_data, add_noise, get_graph, get_graph_magic, visuallize_graph, denoise_experiment, compare_denoised_signal
import numpy as np
from sklearn.datasets import make_blobs
## the output seems to be too much for this notebook, disabling tqdm.
from tqdm import tqdm
# from functools import partialmethod
# tqdm.__init__ = partialmethod(tqdm.__init__, disable=True)

# %%
np.random.seed(32)
adata = generate_blob_data(n_cells=1000, n_genes=500, n_clusters=3, cluster_std=10.0, center_box=(-5, 5))

# %%
visuallize_graph(get_graph_magic(adata))
# Out:
# Running MAGIC on 1000 cells and 500 genes.
# Calculating graph and diffusion operator...
#   Calculating PCA...
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/magic/magic.py:425: UserWarning: Input matrix contains unexpressed genes. Please remove them prior to running MAGIC.
#   warnings.warn(
#   Calculated PCA in 3.98 seconds.
#   Calculating KNN search...
#   Calculated KNN search in 0.13 seconds.
#   Calculating affinities...
#   Calculated affinities in 0.10 seconds.
# Calculated graph and diffusion operator in 4.22 seconds.
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pygsp/plotting.py:274: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   ax.scatter(G.coords[:, 0], G.coords[:, 1], marker='o',

# %%
visuallize_graph(get_graph(adata))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 visuallize_graph(get_graph(adata))
#
# File ~/Documents/GitHub/Spectral-Denoising/experiment_utils.py:102, in get_graph(adata, k)
#     100 def get_graph(adata, k=10):
#     101     # Perform PCA to reduce the dimensionality
# --> 102     sc.tl.pca(adata)
#     104     # Compute k-nearest neighbors and Gaussian kernel weights
#     105     # k = 10  # You can change this value to the desired number of neighbors
#     106     sc.pp.neighbors(adata, n_neighbors=k, use_rep='X_pca', method='gauss', metric='euclidean', knn=True)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/scanpy/preprocessing/_pca.py:188, in pca(data, n_comps, zero_center, svd_solver, random_state, return_info, use_highly_variable, dtype, copy, chunked, chunk_size)
#     184         X = X.toarray()
#     185     pca_ = PCA(
#     186         n_components=n_comps, svd_solver=svd_solver, random_state=random_state
#     187     )
# --> 188     X_pca = pca_.fit_transform(X)
#     189 elif issparse(X) and zero_center:
#     190     from sklearn.decomposition import PCA
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/utils/_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return (
#     144             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     145             *data_to_wrap[1:],
#     146         )
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:462, in PCA.fit_transform(self, X, y)
#     439 """Fit the model with X and apply the dimensionality reduction on X.
#     440
#     441 Parameters
#    (...)
#     458 C-ordered array, use 'np.ascontiguousarray'.
#     459 """
#     460 self._validate_params()
# --> 462 U, S, Vt = self._fit(X)
#     463 U = U[:, : self.n_components_]
#     465 if self.whiten:
#     466     # X_new = X * V / S * sqrt(n_samples) = U * sqrt(n_samples)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:514, in PCA._fit(self, X)
#     512     return self._fit_full(X, n_components)
#     513 elif self._fit_svd_solver in ["arpack", "randomized"]:
# --> 514     return self._fit_truncated(X, n_components, self._fit_svd_solver)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:609, in PCA._fit_truncated(self, X, n_components, svd_solver)
#     607 if svd_solver == "arpack":
#     608     v0 = _init_arpack_v0(min(X.shape), random_state)
# --> 609     U, S, Vt = svds(X, k=n_components, tol=self.tol, v0=v0)
#     610     # svds doesn't abide by scipy.linalg.svd/randomized_svd
#     611     # conventions, so reverse its outputs.
#     612     S = S[::-1]
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/scipy/sparse/linalg/_eigen/_svds.py:532, in svds(A, k, ncv, tol, which, v0, maxiter, return_singular_vectors, solver, random_state, options)
#     530 if v0 is None:
#     531     v0 = random_state.standard_normal(size=(min(A.shape),))
# --> 532 _, eigvec = eigsh(XH_X, k=k, tol=tol ** 2, maxiter=maxiter,
#     533                   ncv=ncv, which=which, v0=v0)
#     534 # arpack do not guarantee exactly orthonormal eigenvectors
#     535 # for clustered eigenvalues, especially in complex arithmetic
#     536 eigvec, _ = np.linalg.qr(eigvec)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/scipy/sparse/linalg/_eigen/arpack/arpack.py:1697, in eigsh(A, k, M, sigma, which, v0, ncv, maxiter, tol, return_eigenvectors, Minv, OPinv, mode)
#    1695 with _ARPACK_LOCK:
#    1696     while not params.converged:
# -> 1697         params.iterate()
#    1699     return params.extract(return_eigenvectors)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/scipy/sparse/linalg/_eigen/arpack/arpack.py:537, in _SymmetricArpackParams.iterate(self)
#     535 def iterate(self):
#     536     self.ido, self.tol, self.resid, self.v, self.iparam, self.ipntr, self.info = \
# --> 537         self._arpack_solver(self.ido, self.bmat, self.which, self.k,
#     538                             self.tol, self.resid, self.v, self.iparam,
#     539                             self.ipntr, self.workd, self.workl, self.info)
#     541     xslice = slice(self.ipntr[0] - 1, self.ipntr[0] - 1 + self.n)
#     542     yslice = slice(self.ipntr[1] - 1, self.ipntr[1] - 1 + self.n)
#
# KeyboardInterrupt:

# %%
adata_gaussian = add_noise(adata, noise_type='gaussian', mean=0, std=1, noise_scale=1)
adata_uniform1 = add_noise(adata, noise_type='uniform', low=0, high=0.5)
adata_uniform2 = add_noise(adata, noise_type='uniform', low=0.2, high=0.8)
adata_bernoulli = add_noise(adata, noise_type='bernoulli', probability=0.5)

# %%
# pygsp_graph = get_graph(adata_gaussian)
pygsp_graph = get_graph_magic(adata_gaussian)
sig_denoised_gaussian = denoise_experiment(pygsp_graph, adata_gaussian.X, 'gaussian')
mse_dict_gaussian = compare_denoised_signal(adata.X, adata_gaussian.X, sig_denoised_gaussian)
# Out:
# Running MAGIC on 1000 cells and 500 genes.
# Calculating graph and diffusion operator...
#   Calculating PCA...
#   Calculated PCA in 3.85 seconds.
#   Calculating KNN search...
#   Calculated KNN search in 0.13 seconds.
#   Calculating affinities...
#   Calculated affinities in 0.09 seconds.
# Calculated graph and diffusion operator in 4.07 seconds.
# 2023-05-08 11:02:14,722:[WARNING](pygsp.graphs.graph.lmax): The largest eigenvalue G.lmax is not available, we need to estimate it. Explicitly call G.estimate_lmax() or G.compute_fourier_basis() once beforehand to suppress the warning.

# %%
# pygsp_graph = get_graph(adata_bernoulli)
pygsp_graph = get_graph_magic(adata_bernoulli)
sig_denoised_bernoulli = denoise_experiment(pygsp_graph, adata_bernoulli.X, 'bernoulli')
mse_dict_bernoulli = compare_denoised_signal(adata.X, adata_bernoulli.X, sig_denoised_gaussian)
# Out:
# Running MAGIC on 1000 cells and 500 genes.
# Calculating graph and diffusion operator...
#   Calculating PCA...
#   Calculated PCA in 3.80 seconds.
#   Calculating KNN search...
#   Calculated KNN search in 0.14 seconds.
#   Calculating affinities...
#   Calculated affinities in 0.09 seconds.
# Calculated graph and diffusion operator in 4.08 seconds.
#   3%|█                                       | 14/500 [00:00<00:00, 2240.03it/s]
#   3%|█                                       | 13/500 [00:00<00:00, 2445.88it/s]
#   3%|█▎                                      | 16/500 [00:00<00:00, 4285.92it/s]
#   2%|▉                                        | 12/500 [00:00<00:00, 855.97it/s]
#   3%|█                                       | 13/500 [00:00<00:00, 8115.19it/s]
#   3%|█▏                                       | 14/500 [00:00<00:00, 736.69it/s]
#   2%|▉                                       | 12/500 [00:00<00:00, 1330.50it/s]
#   3%|█                                       | 14/500 [00:00<00:00, 1020.48it/s]
#   3%|█                                       | 14/500 [00:00<00:00, 1595.10it/s]
#   2%|▉                                        | 12/500 [00:00<00:00, 527.12it/s]
#   3%|█                                       | 14/500 [00:00<00:00, 2188.20it/s]
#   3%|█▎                                       | 16/500 [00:00<00:00, 792.62it/s]
#   3%|█                                      | 13/500 [00:00<00:00, 10718.69it/s]
#   3%|█▎                                      | 16/500 [00:00<00:00, 2777.80it/s]
#   3%|█                                      | 13/500 [00:00<00:00, 10840.15it/s]
#   2%|▉                                       | 12/500 [00:00<00:00, 5705.89it/s]
#   3%|█                                       | 14/500 [00:00<00:00, 9627.85it/s]
#   3%|█▎                                      | 16/500 [00:00<00:00, 1358.59it/s]
#   2%|▊                                       | 10/500 [00:00<00:00, 2120.91it/s]
#   2%|▉                                      | 12/500 [00:00<00:00, 10496.69it/s]
#   2%|▉                                        | 12/500 [00:00<00:00, 996.75it/s]
#   2%|▉                                       | 12/500 [00:00<00:00, 1102.72it/s]
#   2%|▉                                       | 12/500 [00:00<00:00, 1119.73it/s]
#   3%|█                                       | 14/500 [00:00<00:00, 1230.57it/s]
#   3%|█                                       | 14/500 [00:00<00:00, 2608.63it/s]
#   3%|█                                        | 13/500 [00:00<00:00, 778.92it/s]
#   3%|█                                       | 14/500 [00:00<00:00, 5294.88it/s]
#   3%|█                                       | 14/500 [00:00<00:00, 1260.69it/s]
#   2%|▉                                       | 12/500 [00:00<00:00, 1471.69it/s]
#   3%|█▏                                      | 15/500 [00:00<00:00, 6756.29it/s]
#   3%|█                                       | 13/500 [00:00<00:00, 5079.74it/s]
#   2%|▉                                       | 11/500 [00:00<00:00, 8821.67it/s]
#   2%|▉                                       | 12/500 [00:00<00:00, 9556.04it/s]
#   3%|█                                        | 13/500 [00:00<00:00, 701.79it/s]
#   3%|█▏                                       | 15/500 [00:00<00:00, 966.82it/s]
#   2%|▉                                        | 12/500 [00:00<00:00, 709.86it/s]
#   3%|█                                        | 13/500 [00:00<00:00, 960.12it/s]
#   3%|█                                       | 13/500 [00:00<00:00, 1300.13it/s]
#   3%|█                                       | 14/500 [00:00<00:00, 1158.56it/s]
#   3%|█▏                                       | 15/500 [00:00<00:00, 904.15it/s]
#   3%|█                                       | 14/500 [00:00<00:00, 
/s]
#   3%|█                                       | 13/500 [00:00<00:00, 7304.21it/s]
#   3%|█▏                                      | 15/500 [00:00<00:00, 2514.77it/s]
#   3%|█                                       | 13/500 [00:00<00:00, 1270.11it/s]
#   3%|█                                      | 14/500 [00:00<00:00, 11364.48it/s]
#   2%|▊                                      | 11/500 [00:00<00:00, 10966.80it/s]
#   3%|█                                      | 14/500 [00:00<00:00, 11639.30it/s]
#   3%|█                                       | 13/500 [00:00<00:00, 2251.09it/s]
#   3%|█                                       | 13/500 [00:00<00:00, 3359.79it/s]
#   2%|▉                                       | 12/500 [00:00<00:00, 2339.27it/s]
#   3%|█                                       | 14/500 [00:00<00:00, 3186.99it/s]
#   3%|█                                       | 14/500 [00:00<00:00, 5068.65it/s]
#   3%|█▏                                      | 15/500 [00:00<00:00, 1805.30it/s]
#   3%|█▎                                     | 17/500 [00:00<00:00, 12346.87it/s]
#   2%|▊                                        | 10/500 [00:00<00:01, 405.40it/s]
#   2%|▉                                       | 12/500 [00:00<00:00, 1931.75it/s]
#   3%|█                                       | 14/500 [00:00<00:00, 2198.85it/s]
#   2%|▉                                       | 12/500 [00:00<00:00, 3000.75it/s]
#   2%|▉                                        | 11/500 [00:00<00:00, 785.54it/s]
#   3%|█▏                                      | 15/500 [00:00<00:00, 2413.94it/s]
#   3%|█▏                                      | 15/500 [00:00<00:00, 3791.63it/s]
#   3%|█                                       | 14/500 [00:00<00:00, 2508.98it/s]
#   3%|█                                       | 14/500 [00:00<00:00, 4503.43it/s]
#   3%|█                                       | 13/500 [00:00<00:00, 3361.86it/s]
#   3%|█▏                                       | 14/500 [00:00<00:00, 903.17it/s]
#   3%|█                                       | 14/500 [00:00<00:00, 1031.48it/s]
#   3%|█                                       | 14/500 [00:00<00:00, 1799.96it/s]
#   3%|█                                       | 14/500 [00:00<00:00, 1063.02it/s]
#   3%|█                                       | 14/500 [00:00<00:00, 1683.06it/s]
#   3%|█                                       | 14/500 [00:00<00:00, 3771.61it/s]
#   3%|█▎                                      | 16/500 [00:00<00:00, 1389.85it/s]
#   3%|█▎                                      | 16/500 [00:00<00:00, 4248.47it/s]
#   3%|█                                       | 14/500 [00:00<00:00, 1403.48it/s]
#   3%|█                                       | 14/500 [00:00<00:00, 4229.96it/s]
#   3%|█                                       | 14/500 [00:00<00:00, 4257.87it/s]
#   3%|█                                       | 14/500 [00:00<00:00, 3211.21it/s]
#   3%|█                                       | 14/500 [00:00<00:00, 4345.14it/s]
#   3%|█                                       | 13/500 [00:00<00:00, 3734.91it/s]
#   3%|█                                       | 14/500 [00:00<00:00, 3708.49it/s]
#   3%|█                                      | 14/500 [00:00<00:00, 10280.16it/s]
#   2%|▉                                       | 12/500 [00:00<00:00, 2267.60it/s]
#   3%|█                                       | 14/500 [00:00<00:00, 3810.53it/s]
#   3%|█                                       | 14/500 [00:00<00:00, 4367.77it/s]
#   2%|▉                                       | 11/500 [00:00<00:00, 1481.13it/s]
#   3%|█▏                                       | 14/500 [00:00<00:00, 855.74it/s]
#   3%|█                                       | 13/500 [00:00<00:00, 2518.40it/s]
#   3%|█                                       | 13/500 [00:00<00:00, 9775.18it/s]
#   3%|█                                      | 13/500 [00:00<00:00, 10672.53it/s]
#   2%|▉                                       | 12/500 [00:00<00:00, 3276.80it/s]
#   2%|▉                                       | 12/500 [00:00<00:00, 5141.65it/s]
#   2%|▉                                       | 12/500 [00:00<00:00, 1766.77it/s]
#   2%|▉                                       | 12/500 [00:00<00:00, 1948.80it/s]
#   3%|█▏                                      | 15/500 [00:00<00:00, 1679.15it/s]
#   3%|█                                        | 13/500 [00:00<00:00, 938.82it/s]
#   3%|█                                       | 14/500 [00:00<00:00, 3943.87it/s]
#   2%|▉                                        | 11/500 [00:00<00:00, 705.12it/s]
#   3%|█                                       | 13/500 [00:00<00:00, 2050.77it/s]
#   3%|█▏                                     | 16/500 [00:00<00:00, 12306.78it/s]
#   2%|▋                                        | 8/500 [00:00<00:00, 1062.86it/s]
#   3%|█▏                                      | 15/500 [00:00<00:00, 2468.21it/s]
#   3%|█                                       | 13/500 [00:00<00:00, 3745.17it/s]
#   3%|█▎                                      | 16/500 [00:00<00:00, 1402.40it/s]
#   3%|█                                       | 14/500 [00:00<00:00, 3910.25it/s]
#   3%|█                                       | 13/500 [00:00<00:00, 2104.52it/s]
#   3%|█                                      | 13/500 [00:00<00:00, 11123.21it/s]
#   3%|█                                       | 14/500 [00:00<00:00, 2891.34it/s]
#   3%|█                                       | 14/500 [00:00<00:00, 3041.55it/s]
#   3%|█                                       | 14/500 [00:00<00:00, 1703.81it/s]
#   2%|▉                                       | 11/500 [00:00<00:00, 2170.05it/s]

# %%
mse_dict_gaussian
# Out:
# {'MSE noisy': 1.0016468,
#  'MSE denoised': 0.5901012849344922,
#  'MSE denoised vs noisy': 1.0170418429181802}

# %%
mse_dict_bernoulli
# Out:
# {'MSE noisy': 0.49777067,
#  'MSE denoised': 0.5901012849344922,
#  'MSE denoised vs noisy': 0.3928377251010346}

# %%
# pygsp_graph = get_graph_magic(adata_uniform1)
sig_denoised_uniform1 = denoise_experiment(pygsp_graph, adata_uniform1.X, 'uniform')
mse_dict_uniform1 = compare_denoised_signal(adata.X, adata_uniform1.X, sig_denoised_gaussian)
# Out:
# Running MAGIC on 1000 cells and 500 genes.
# Calculating graph and diffusion operator...
#   Calculating PCA...
#   Calculated PCA in 3.60 seconds.
#   Calculating KNN search...
#   Calculated KNN search in 0.09 seconds.
#   Calculating affinities...
#   Calculated affinities in 0.08 seconds.
# Calculated graph and diffusion operator in 3.82 seconds.
# 0.5331879361765712
# Truth unknown
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[14], line 2
#       1 pygsp_graph = get_graph_magic(adata_uniform1)
# ----> 2 sig_denoised_uniform1 = denoise_experiment(pygsp_graph, adata_uniform1.X, 'uniform')
#       3 mse_dict_uniform1 = compare_denoised_signal(adata.X, adata_uniform1.X, sig_denoised_gaussian)
#
# File ~/Documents/GitHub/Spectral-Denoising/experiment_utils.py:165, in denoise_experiment(pygsp_graph, signal_noisy, noise_type)
#     163     signal_denoised = Denoising_Machine.remove_bernoulli_noise(signal_noisy, method = 'approximate', time = 500)
#     164 elif noise_type == 'uniform':
# --> 165     signal_denoised = Denoising_Machine.remove_uniform_noise(signal_noisy)
#     166 else: raise ValueError('noise type not recognized')
#     167 return signal_denoised
#
# File ~/Documents/GitHub/Spectral-Denoising/spectral_denoiser.py:270, in Spectral_Denoiser.remove_uniform_noise(self, theta_tilde, max_iter, true_signal, max_iter_qp, epsilon, bump, eta, method, lr)
#     267 losses.append(primal_cost(x_k))
#     269 if method == 'ccp':
# --> 270     x_k = convex_subroutine(eta*Lap, noisy_signal, x_k)
#     272 elif method == 'pg':
#     273     x_k.reshape(-1,1)
#
# File ~/Documents/GitHub/Spectral-Denoising/spectral_denoiser.py:230, in Spectral_Denoiser.remove_uniform_noise.<locals>.convex_subroutine(L_sub, theta_tilde_sub, x_k)
#     227     Uniform_Enforcer_Matrix[i,i] = - 1/theta_tilde_sub[i]
#     229 concave_gradient = (1/np.abs(x_k)).reshape(-1,1)
# --> 230 x_k_plus_1 = qp(matrix(L_sub.astype(np.double)), matrix(concave_gradient), matrix(Uniform_Enforcer_Matrix), matrix(Uniform_Enforcer_Vector))['x']
#     232 return np.array(x_k_plus_1).reshape(-1,1)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/cvxopt/coneprog.py:4485, in qp(P, q, G, h, A, b, solver, kktsolver, initvals, **kwargs)
#    4475         pinfres, dinfres = None, None
#    4477     return {'status': status, 'x': x, 's': s, 'y': y, 'z': z,
#    4478         'primal objective': pcost, 'dual objective': dcost,
#    4479         'gap': gap, 'relative gap': relgap,
#    (...)
#    4482         'residual as primal infeasibility certificate': pinfres,
#    4483         'residual as dual infeasibility certificate': dinfres}
# -> 4485 return coneqp(P, q, G, h, None, A,  b, initvals, kktsolver = kktsolver, options = options)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/cvxopt/coneprog.py:1764, in coneqp(P, q, G, h, dims, A, b, initvals, kktsolver, xnewcopy, xdot, xaxpy, xscal, ynewcopy, ydot, yaxpy, yscal, **kwargs)
#    1444 """
#    1445
#    1446 Solves a pair of primal and dual convex quadratic cone programs
#    (...)
#    1761
#    1762 """
#    1763 import math
# -> 1764 from cvxopt import base, blas, misc
#    1765 from cvxopt.base import matrix, spmatrix
#    1767 STEP = 0.99
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/cvxopt/misc.py:21
#       1 # Copyright 2012-2022 M. Andersen and L. Vandenberghe.
#       2 # Copyright 2010-2011 L. Vandenberghe.
#       3 # Copyright 2004-2009 J. Dahl and L. Vandenberghe.
#    (...)
#      17 # You should have received a copy of the GNU General Public License
#      18 # along with this program.  If not, see <http://www.gnu.org/licenses/>.
#      20 import math
# ---> 21 from cvxopt import base, blas, lapack, cholmod, misc_solvers
#      22 from cvxopt.base import matrix, spmatrix
#      23 __all__ = []
#
# ImportError: dlopen(/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/cvxopt/cholmod.cpython-310-darwin.so, 0x0002): symbol not found in flat namespace '_cholmod_l_allocate_dense'

# %%
pygsp_graph = get_graph(adata_uniform2)
sig_denoised_uniform2 = denoise_experiment(pygsp_graph, adata_uniform2.X, 'uniform')
mse_dict_uniform2 = compare_denoised_signal(adata.X, adata_uniform2.X, sig_denoised_gaussian)
# Out:
# /gpfs/gibbs/pi/krishnaswamy_smita/xingzhi/Spectral-Denoising/experiment_utils.py:109: FutureWarning: This location for 'connectivities' is deprecated. It has been moved to .obsp[connectivities], and will not be accesible here in a future version of anndata.
#   graph = adata.uns['neighbors']['connectivities']
# -25774.595211988257
# Truth unknown
# ---------------------------------------------------------------------------
# ArithmeticError                           Traceback (most recent call last)
# File ~/myconda/conda_envs/sc/lib/python3.10/site-packages/cvxopt/misc.py:1429, in kkt_chol2.<locals>.factor(W, H, Df)
#    1428 if type(F['S']) is matrix:
# -> 1429     lapack.potrf(F['S'])
#    1430 else:
#
# ArithmeticError: 1
#
# During handling of the above exception, another exception occurred:
#
# ArithmeticError                           Traceback (most recent call last)
# File ~/myconda/conda_envs/sc/lib/python3.10/site-packages/cvxopt/coneprog.py:2065, in coneqp(P, q, G, h, dims, A, b, initvals, kktsolver, xnewcopy, xdot, xaxpy, xscal, ynewcopy, ydot, yaxpy, yscal, **kwargs)
#    2064 for rti in W['rti']: rti[::rti.size[0]+1 ] = 1.0
# -> 2065 try: f = kktsolver(W)
#    2066 except ArithmeticError:
#
# File ~/myconda/conda_envs/sc/lib/python3.10/site-packages/cvxopt/coneprog.py:1981, in coneqp.<locals>.kktsolver(W)
#    1980 def kktsolver(W):
# -> 1981     return factor(W, P)
#
# File ~/myconda/conda_envs/sc/lib/python3.10/site-packages/cvxopt/misc.py:1444, in kkt_chol2.<locals>.factor(W, H, Df)
#    1443 if type(F['S']) is matrix:
# -> 1444     lapack.potrf(F['S'])
#    1445 else:
#
# ArithmeticError: 1
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /gpfs/gibbs/pi/krishnaswamy_smita/xingzhi/Spectral-Denoising/experiment_blob_graph.ipynb Cell 11 in <cell line: 2>()
#       <a href='vscode-notebook-cell://ssh-remote%2Bfarnam-gpu01/gpfs/gibbs/pi/krishnaswamy_smita/xingzhi/Spectral-Denoising/experiment_blob_graph.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> pygsp_graph = get_graph(adata_uniform2)
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bfarnam-gpu01/gpfs/gibbs/pi/krishnaswamy_smita/xingzhi/Spectral-Denoising/experiment_blob_graph.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> sig_denoised_uniform2 = denoise_experiment(pygsp_graph, adata_uniform2.X, 'uniform')
#       <a href='vscode-notebook-cell://ssh-remote%2Bfarnam-gpu01/gpfs/gibbs/pi/krishnaswamy_smita/xingzhi/Spectral-Denoising/experiment_blob_graph.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> mse_dict_uniform2 = compare_denoised_signal(adata.X, adata_uniform2.X, sig_denoised_gaussian)
#
# File /gpfs/gibbs/pi/krishnaswamy_smita/xingzhi/Spectral-Denoising/experiment_utils.py:165, in denoise_experiment(pygsp_graph, signal_noisy, noise_type)
#     163     signal_denoised = Denoising_Machine.remove_bernoulli_noise(signal_noisy, method = 'approximate', time = 500)
#     164 elif noise_type == 'uniform':
# --> 165     signal_denoised = Denoising_Machine.remove_uniform_noise(signal_noisy)
#     166 else: raise ValueError('noise type not recognized')
#     167 return signal_denoised
#
# File /gpfs/gibbs/pi/krishnaswamy_smita/xingzhi/Spectral-Denoising/spectral_denoiser.py:268, in Spectral_Denoiser.remove_uniform_noise(self, theta_tilde, max_iter, true_signal, max_iter_qp, epsilon, bump, eta)
#     266 prev_cost = new_cost
#     267 losses.append(primal_cost(x_k))
# --> 268 x_k = convex_subroutine(eta*Lap, noisy_signal, x_k)
#     269 new_cost = primal_cost(x_k)
#     270 delta = prev_cost - new_cost
#
# File /gpfs/gibbs/pi/krishnaswamy_smita/xingzhi/Spectral-Denoising/spectral_denoiser.py:231, in Spectral_Denoiser.remove_uniform_noise.<locals>.convex_subroutine(L_sub, theta_tilde_sub, x_k)
#     227     Uniform_Enforcer_Matrix[i,i] = - 1/theta_tilde_sub[i]
#     230 concave_gradient = (1/np.abs(x_k)).reshape(-1,1)
# --> 231 x_k_plus_1 = qp(matrix(L_sub.astype(np.double)), matrix(concave_gradient), matrix(Uniform_Enforcer_Matrix), matrix(Uniform_Enforcer_Vector))['x']
#     233 return np.array(x_k_plus_1).reshape(-1,1)
#
# File ~/myconda/conda_envs/sc/lib/python3.10/site-packages/cvxopt/coneprog.py:4485, in qp(P, q, G, h, A, b, solver, kktsolver, initvals, **kwargs)
#    4475         pinfres, dinfres = None, None
#    4477     return {'status': status, 'x': x, 's': s, 'y': y, 'z': z,
#    4478         'primal objective': pcost, 'dual objective': dcost,
#    4479         'gap': gap, 'relative gap': relgap,
#    (...)
#    4482         'residual as primal infeasibility certificate': pinfres,
#    4483         'residual as dual infeasibility certificate': dinfres}
# -> 4485 return coneqp(P, q, G, h, None, A,  b, initvals, kktsolver = kktsolver, options = options)
#
# File ~/myconda/conda_envs/sc/lib/python3.10/site-packages/cvxopt/coneprog.py:2067, in coneqp(P, q, G, h, dims, A, b, initvals, kktsolver, xnewcopy, xdot, xaxpy, xscal, ynewcopy, ydot, yaxpy, yscal, **kwargs)
#    2065 try: f = kktsolver(W)
#    2066 except ArithmeticError:
# -> 2067     raise ValueError("Rank(A) < p or Rank([P; A; G]) < n")
#    2070 # Solve
#    2071 #
#    2072 #     [ P   A'  G' ]   [ x ]   [ -q ]
#    2073 #     [ A   0   0  ] * [ y ] = [  b ].
#    2074 #     [ G   0  -I  ]   [ z ]   [  h ]
#    2076 xcopy(q, x)
#
# ValueError: Rank(A) < p or Rank([P; A; G]) < n

# %%
import magic

# %%
magic_op = magic.MAGIC()
magic_denoised_gaussian = magic_op.fit_transform(adata_gaussian.X)
magic_mse_dict_gaussian = compare_denoised_signal(adata.X, adata_gaussian.X, magic_denoised_gaussian)
# Out:
# Calculating MAGIC...
#   Running MAGIC on 1000 cells and 500 genes.
#   Calculating graph and diffusion operator...
#     Calculating PCA...
#     Calculated PCA in 0.47 seconds.
#     Calculating KNN search...
#     Calculated KNN search in 0.19 seconds.
#     Calculating affinities...
#     Calculated affinities in 0.12 seconds.
#   Calculated graph and diffusion operator in 0.80 seconds.
#   Calculating imputation...
#   Calculated imputation in 0.07 seconds.
# Calculated MAGIC in 0.88 seconds.

# %%
magic_op = magic.MAGIC()
magic_denoised_bernoulli = magic_op.fit_transform(adata_bernoulli.X)
magic_mse_dict_bernoulli = compare_denoised_signal(adata.X, adata_bernoulli.X, magic_denoised_bernoulli)
# Out:
# Calculating MAGIC...
#   Running MAGIC on 1000 cells and 500 genes.
#   Calculating graph and diffusion operator...
#     Calculating PCA...
#     Calculated PCA in 0.05 seconds.
#     Calculating KNN search...
#     Calculated KNN search in 0.10 seconds.
#     Calculating affinities...
#     Calculated affinities in 0.10 seconds.
#   Calculated graph and diffusion operator in 0.27 seconds.
#   Calculating imputation...
#   Calculated imputation in 0.02 seconds.
# Calculated MAGIC in 0.30 seconds.

# %%
magic_op = magic.MAGIC()
magic_denoised_uniform1 = magic_op.fit_transform(adata_uniform1.X)
magic_mse_dict_uniform1 = compare_denoised_signal(adata.X, adata_uniform1.X, magic_denoised_uniform1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /gpfs/gibbs/pi/krishnaswamy_smita/xingzhi/Spectral-Denoising/experiment_blob_graph.ipynb Cell 14 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bfarnam-gpu01/gpfs/gibbs/pi/krishnaswamy_smita/xingzhi/Spectral-Denoising/experiment_blob_graph.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> magic_op = magic.MAGIC()
#       <a href='vscode-notebook-cell://ssh-remote%2Bfarnam-gpu01/gpfs/gibbs/pi/krishnaswamy_smita/xingzhi/Spectral-Denoising/experiment_blob_graph.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> magic_denoised_uniform1 = magic_op.fit_transform(adata_uniform1.X)
#       <a href='vscode-notebook-cell://ssh-remote%2Bfarnam-gpu01/gpfs/gibbs/pi/krishnaswamy_smita/xingzhi/Spectral-Denoising/experiment_blob_graph.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> magic_mse_dict_uniform1 = compare_denoised_signal(adata.X, adata_uniform1.X, magic_denoised_uniform1)
#
# NameError: name 'magic' is not defined

# %%
magic_op = magic.MAGIC()
magic_denoised_uniform2 = magic_op.fit_transform(adata_uniform2.X)
magic_mse_dict_uniform2 = compare_denoised_signal(adata.X, adata_uniform2.X, magic_denoised_uniform2)
# Out:
# Calculating MAGIC...
#   Running MAGIC on 1000 cells and 500 genes.
#   Calculating graph and diffusion operator...
#     Calculating PCA...
#     Calculated PCA in 0.07 seconds.
#     Calculating KNN search...
#     Calculated KNN search in 0.10 seconds.
#     Calculating affinities...
#     Calculated affinities in 0.10 seconds.
#   Calculated graph and diffusion operator in 0.29 seconds.
#   Calculating imputation...
#   Calculated imputation in 0.02 seconds.
# Calculated MAGIC in 0.31 seconds.

# %%
magic_mse_dict_gaussian
# Out:
# {'MSE noisy': 1.0034318,
#  'MSE denoised': 0.9000126774822231,
#  'MSE denoised vs noisy': 1.8241447767925283}

# %%
magic_mse_dict_bernoulli
# Out:
# {'MSE noisy': 0.500934,
#  'MSE denoised': 0.9482997499555483,
#  'MSE denoised vs noisy': 0.4567380247112652}
