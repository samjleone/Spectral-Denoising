# %%
from PIL import Image
import pygsp.graphs as graphs
import numpy as np
import matplotlib.pyplot as plt
import spectral_denoiser
import importlib
from tqdm import tqdm
import pandas as pd

importlib.reload(spectral_denoiser)

N = 32
# True_Image = np.asarray(Image.open("noodle.jpg").resize((N,N)))
# Theta = True_Image.reshape(-1,3)
G = graphs.Grid2d(N)

# %%
def unpickle(file):
    import pickle
    with open(file, 'rb') as fo:
        dict = pickle.load(fo, encoding='bytes')
    return dict

cifar = unpickle('cifar-10-batches-py/data_batch_1')
images = cifar[b'data'][:100]

def transform(im):
    img = np.zeros((N,N,3))
    img[:,:,0] = im[:1024].reshape(N,N)
    img[:,:,1] = im[1024:2048].reshape(N,N)
    img[:,:,2] = im[2048:].reshape(N,N)
    return img.astype(np.uint8)

images = [transform(x) for x in images]

# %%
np.random.seed(0)
sd = spectral_denoiser.Spectral_Denoiser(G)

def run_experiment(Theta, Noisy_Image):
    best_restores = []
    best_MSEs = []

    Restored_avgs = []
    MSE_avgs = []
    Restored_NN = []
    MSE_NN = []

    Restored_sd = sd.remove_gaussian_noise(Noisy_Image.reshape(-1,3))
    MSE_sd = np.linalg.norm(Restored_sd - Theta)

    for t in [1,5,10,20]:
        restored_avgs = sd.local_average(Noisy_Image, t=t)
        Restored_avgs.append(restored_avgs)
        MSE_avgs.append(np.linalg.norm(restored_avgs - Theta))

    Best_MSE_avgs = np.min(MSE_avgs)
    Best_avgs_Restoration = Restored_avgs[np.argmin(best_MSE_avgs)]

    for tau in [50, 100, 500, 1000]:
        restored_nn = sd.nuclear_norm_appx(Noisy_Image.reshape(N,N,3), tau=tau)
        Restored_NN.append(restored_nn)
        MSE_NN.append(np.linalg.norm(restored_nn - Theta.reshape(N,N,3)))

    Best_MSE_NN = np.min(MSE_NN)
    Best_NN_Restoration = Restored_NN[np.argmin(best_MSE_NN)]

    best_MSEs.append([MSE_sd, Best_MSE_avgs, Best_MSE_NN])
    best_restores.append([Restored_sd, Best_avgs_Restoration, Best_NN_Restoration])
    
    return best_MSEs

# %%
MSEs = {}
for sigma in tqdm([5,25,50,100]):
    theta = np.array(images).reshape(-1,3)
    T = theta.shape[0]*theta.shape[1]
    noisy = (np.random.randn(T).reshape(-1,3)*sigma + theta)
    tau = sd.estimate_tau_for_gaussian(noisy)
    MSEs[sigma] = np.mean([run_experiment(Theta=a, Noisy_Image=b, tau=tau) for a,b in zip(theta,noisy)],axis=0)
# Out:
#   0%|                                                     | 0/4 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[356], line 6
#       4 T = theta.shape[0]*theta.shape[1]
#       5 noisy = (np.random.randn(T).reshape(-1,3)*sigma + theta).reshape(-1,3)
# ----> 6 tau = sd.estimate_tau_for_gaussian(noisy)
#       7 MSEs[sigma] = np.mean([run_experiment(Theta=a, Noisy_Image=b, tau=tau) for a,b in zip(theta,noisy)],axis=0)
#
# File ~/Documents/GitHub/Spectral-Denoising/spectral_denoiser.py:198, in Spectral_Denoiser.estimate_tau_for_gaussian(self, tilde_samples)
#     196 for i in range(num_samps):
#     197     theta_tilde = tilde_samples[:,i]
# --> 198     order_1 += theta_tilde.T@Lap@theta_tilde
#     199     order_2 += np.linalg.norm(Lap@theta_tilde)**2
#     201 order_1 = order_1/num_samps; order_2 = order_2/num_samps
#
# ValueError: matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 1024 is different from 102400)

# %%
MSEs
# Out:
# {5: array([[1685.15221353, 1758.15196262, 2629.28169356]]),
#  25: array([[1705.87830273, 1760.25923511, 2627.56791662]]),
#  50: array([[1689.77589272, 1758.59549952, 2628.52231802]]),
#  100: array([[1684.71476729, 1757.11100209, 2628.41679152]])}

# %%
fig, ax = plt.subplots(1,5, figsize=(50,10))
ax[0].imshow(True_Image.reshape(N,N,3).astype(np.uint8))
ax[0].set_title("Original Image",fontsize=50)
ax[1].imshow(Noisy_Image.reshape(N,N,3).astype(np.uint8))
ax[1].set_title("Noisy Image \n (Sigma = 50)",fontsize=50)
ax[2].imshow(best_restores[-2][0].reshape(N,N,3).astype(np.uint8))
ax[2].set_title("Spectral Restoration",fontsize=50)
ax[3].imshow(best_restores[-2][1].reshape(N,N,3).astype(np.uint8))
ax[3].set_title("Local Averaging \n Best Restoration",fontsize=50)
ax[4].imshow(best_restores[-2][2].reshape(N,N,3).astype(np.uint8))
ax[4].set_title("Nuclear Norm \n Best Restoration",fontsize=50)

plt.savefig("Image_Comparison_Visualization.png")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[321], line 2
#       1 fig, ax = plt.subplots(1,5, figsize=(50,10))
# ----> 2 ax[0].imshow(True_Image.reshape(N,N,3).astype(np.uint8))
#       3 ax[0].set_title("Original Image",fontsize=50)
#       4 ax[1].imshow(Noisy_Image.reshape(N,N,3).astype(np.uint8))
#
# ValueError: cannot reshape array of size 67500 into shape (32,32,3)

# %%
fig, ax = plt.subplots(1,3, figsize=(30,10))

ax[0].imshow(Restored_sd.reshape(N,N,3).astype(np.uint8))
ax[1].imshow(Restored_avgs[-1].reshape(N,N,3).astype(np.uint8))
ax[2].imshow(Restored_NN[-1].reshape(N,N,3).astype(np.uint8))

# %%
df = pd.DataFrame()
df['Spectral'] = [np.round(x[0],2) for x in best_MSEs]
df['Local Avg.'] = [np.round(x[1],2) for x in best_MSEs]
df['Nuclear Norm'] = [np.round(x[2],2) for x in best_MSEs]
df.index = [5,25,50,100]

df.head()
# Out:
#      Spectral  Local Avg.  Nuclear Norm
# 5     1627.21     1327.06       1059.27
# 25    2831.70     2762.33       3675.03
# 50    3478.45     3818.64       5449.32
# 100   4740.07     5116.65      11944.32

# %%
print(df.to_latex())
# Out:
# \begin{tabular}{lrrr}
# \toprule
# {} &  Spectral &  Local Avg. &  Nuclear Norm \\
# \midrule
# 5   &   1627.21 &     1327.06 &       1059.27 \\
# 25  &   2831.70 &     2762.33 &       3675.03 \\
# 50  &   3478.45 &     3818.64 &       5449.32 \\
# 100 &   4740.07 &     5116.65 &      11944.32 \\
# \bottomrule
# \end{tabular}
